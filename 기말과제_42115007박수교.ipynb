# %% [markdown]
# <a href="https://colab.research.google.com/github/soogyo-park/Python-b-42115007/blob/main/%EA%B8%B0%EB%A7%90%EA%B3%BC%EC%A0%9C_42115007%EB%B0%95%EC%88%98%EA%B5%90.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Python3 샘플 코드 #


import requests

url = 'http://apis.data.go.kr/B552584/OzYlwsndOccrrncInforInqireSvc/getOzAdvsryOccrrncInfo'
para ={'serviceKey' : 'CwHjDBkvbUuWT12u9+lJYV4KNd6sd99rJeSpBPh+NNBn3fE1Deaz641+aYRhFBfZbo6j8YAggG7U4tc06djfGw==', 'returnType' : 'json', 'numOfRows' : '100', 'pageNo' : '1', 'year' : '2013' }

res = requests.get(url, params=para)
print(res.content)
# Out:
# b'{"response":{"body":{"totalCount":160,"items":[{"clearVal":"0.086","sn":"178","maxVal":"0.127","districtName":"\xec\xa0\x84\xeb\x82\xa8","dataDate":"2013-08-28","issueVal":"0.127","issueLvl":null,"issueTime":"13","moveName":"\xec\x88\x9c\xec\xb2\x9c\xec\x8b\x9c","clearTime":"15"},{"clearVal":"0.088","sn":"179","maxVal":"0.155","districtName":"\xec\xa0\x84\xeb\x82\xa8","dataDate":"2013-08-28","issueVal":"0.155","issueLvl":null,"issueTime":"14","moveName":"\xea\xb4\x91\xec\x96\x91\xec\x8b\x9c","clearTime":"15"},{"clearVal":"0.113","sn":"176","maxVal":"0.141","districtName":"\xea\xb2\xbd\xeb\x82\xa8","dataDate":"2013-08-27","issueVal":"0.141","issueLvl":null,"issueTime":"16","moveName":"\xec\xa7\x84\xec\xa3\xbc\xec\x8b\x9c","clearTime":"18"},{"clearVal":"0.096","sn":"177","maxVal":"0.123","districtName":"\xec\x9a\xb8\xec\x82\xb0","dataDate":"2013-08-27","issueVal":"0.123","issueLvl":null,"issueTime":"16","moveName":"\xeb\x8f\x99\xea\xb5\xac \xec\xa0\x84\xec\x97\xad","clearTime":"17"},
# ...

# %%
import json
json_file = json.loads(res.text)

# %%
import pandas as pd
from pandas import json_normalize

df = json_normalize(json_file['response']['body']['items'])
df
# Out:
#    clearVal   sn maxVal districtName    dataDate issueVal issueLvl issueTime  \
# 0     0.086  178  0.127           전남  2013-08-28    0.127     None        13
# 1     0.088  179  0.155           전남  2013-08-28    0.155     None        14
# 2     0.113  176  0.141           경남  2013-08-27    0.141     None        16
# 3     0.096  177  0.123           울산  2013-08-27    0.123     None        16
# 4     0.104  175  0.152           경남  2013-08-27    0.132     None        15
# ..      ...  ...    ...          ...         ...      ...      ...       ...
# 95    0.106   72  0.124           충남  2013-06-08    0.124     None        16
# 96    0.118   69  0.128           경기  2013-06-07    0.128     None        17
# 97    0.112   68  0.127           서울  2013-06-07    0.127     None        16
# 98    0.118   67  0.121           경남  2013-06-06    0.121     None        16
# 99    0.076   66  0.128           대구  2013-06-06    0.128     None        16
#
#        moveName clearTime
# ...

# %%
df.to_excel("output.xlsx")
df.to_csv("output.csv")
